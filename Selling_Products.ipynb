# %%
import json

fd = open("records.json",'r')
r = fd.read()
fd.close()

products = json.loads(r)

print("Welcome.....")

ui_prod = input("Enter the product Id: ")
ui_quan = int(input("Enter the quantity of the Product: "))

for i in products.keys():
    while ui_prod == i:
        if ui_quan <= products[i]['quan']:
            print("****************************************")
            print("             Product:",records[ui_prod]['name'])
            print("               Price:",records[ui_prod]['price'])
            print("         Expiry date:",records[ui_prod]['Expirydate'])
            print('\n')
            print("****************************************")
            print("----------BILLING DETAILS:---------- ")
            print("Total Amount: ",records[ui_prod]['price']*ui_quan*(1-disc)) 
            print("Have a Good Day!!")
            print("Thank You. Visit Us Again")
            print("**********************************")
            records[ui_prod]["qn"] = records[ui_prod]["qn"] - ui_quan
        else:
            print("Sorry. Stock of product you enterd is: ",records[ui_prod]['qn'],"\Aapologies for this inconvenience")
        break
if ui_prod not in records.keys():
   print("Sorry. No product found for ID: ",ui_prod,"\Please enter valid product ID")
    
    
js = json.dumps(records)

fd = open("records.json",'w')
fd.write(js)
fd.close()

## The sold items information is stored on sales.json
fd = open("sales.json",'r')
trans = fd.read()
fd.close()

sales = json.loads(trans)
num = len(sales)+1

sales[num] = {'prod':ui_prod, 'quan' : ui_quan, 'amount': products[ui_prod]['price'] * ui_quan}
sale = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sale)
fd.close()

#Updating Inventory
sales = {1 : {'prod':ui_prod, 'quan':ui_quan, 'amount':products[ui_prod]['price']*ui_quan}}
sal = json.dumps(sales)

fd = open("sales.json",'w')
fd.write(sal)
fd.close()
